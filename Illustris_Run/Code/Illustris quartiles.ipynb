# %%
# %pylab inline
from scipy import optimize
from IPython.display import display, Math, Latex
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Some useful tools and definitions

# %%
#mass units
M = (10.0**10)/0.7
#vol of illustris run
vol = (75.0(0.7)**3
print 75/0.7

# Gives the x,y of the histogram for logmasses from the given array of mass
def histog( mf, nbins ):
    hist, bin_edges = np.histogram(mf, bins = nbins)
    # Obtains the center point for each bin
    xcenter = (bin_edges[:-1] + bin_edges[1:])/2
    return np.array(xcenter), np.array(hist/vol)

# Schechter function
def Schechter(m,alpha,phi_s,m_s):
    MHI = 10.**m
    M_s = 10.**m_s
    return np.log(10.)*phi_s*((MHI/M_s)**(alpha+1))*numpy.exp(-MHI/M_s)

# Returns the fitted parameterts for the Schechter function given a mass distribution
def fit(tmp,bins):
    # tmp[0]:mj,  tmp[1]:nj
    return optimize.curve_fit(Schechter,tmp[0] ,tmp[1],p0=[-2.0,0,12], sigma = np.sqrt(tmp[1]*vol)/vol, maxfev = 100000)
# Out:
# 107.142857143

# %% [markdown]
# ## Loading function

# %%
# loads the file with halo masses and makes the quartiles
# file formated env,mass
# j defines if we treat gass or dm j = 0,1
# minMass minimum mass allowed to have into account a halo
def loadHaloes(name, neigh, j, minMass):
    table = np.loadtxt(name, skiprows = 0, delimiter = ',').T
    #table[0] = neigh/(np.pi*table[0]+1e-9)
    print "number of haloes before: " + str(len(table.T))
    
    # Only take the haloes with not null mass
    lsigma = table[0][where((M*table[j+1]) > minMass)]
    mass = M*table[j+1][where(M*table[j+1]> minMass)]
    
    print "number of haloes after: " + str(len(mass))

    # Calculates the first quartile of logsigma
    global q1
    global q2
    global q3
    global q4
    global q5
    q5 = M*table[j+1][where(M*table[j+1]> minMass)]

    
    q = np.percentile(lsigma,25)
    # Keeps first quartile
    q1 = mass[where(lsigma <= q)]
    # Removes fist quartile from lsigma
    mass = mass[where(lsigma > q)]
    lsigma = lsigma[where(lsigma > q)]
    # Second quartile
    q = np.percentile(lsigma,33.333333)
    q2 = mass[where(lsigma <= q)]
    mass = mass[where(lsigma > q)]
    lsigma = lsigma[where(lsigma > q)]
    # Third and Fourth quartile
    q = np.percentile(lsigma,50)
    q3 = mass[where(lsigma <= q)]
    q4 = mass[where(lsigma >= q)]
    
    # verify the length of each quartile
    print len(q1),len(q2),len(q3),len(q4), sum([len(q1),len(q2),len(q3),len(q4)]),q1,q2,q3,q4,q5

# %% [markdown]
# ## Histogram graphing function

# %%
def histo(bins):
    # Graphics of the mass function for each quartile
    import matplotlib.gridspec as gridspec
    fig, axes = plt.subplots( nrows=2, ncols=4, figsize=(15,20) )
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.3)
    gs = gridspec.GridSpec(4,2)
    ax0 = plt.subplot(gs[0, 0])
    ax1 = plt.subplot(gs[0, 1])
    ax2 = plt.subplot(gs[1, 0])
    ax3 = plt.subplot(gs[1, 1])
    ax4 = plt.subplot(gs[2:,:])
    
    # Callable lists
    axs = [ax0,ax1,ax2,ax3,ax4]
    qs = [q1,q2,q3,q4,q5]
    indx = ['1st quartile','2nd quartile','3rd quartile','4th quartile', 'Total']
    
    for ax,q,i in zip(axs,qs,indx):
        # Histo for first quartile
        tmp = histog(log10(q),bins)
        tmp[1][where(tmp[1]==0)] = 1
        ax.errorbar( tmp[0], log10(tmp[1]), yerr = sqrt(vol*tmp[1])/(vol*tmp[1]), fmt='o', ecolor = 'r', c = 'b', markersize=3,elinewidth=1.5)
        #ax.bar( tmp[0] , log10(tmp[1]), width = tmp[0][1]-tmp[0][2], alpha = 0.4, align = 'center' )
        ax.set_title(i, fontsize = 18)
        ax.set_ylabel('$Log_{10}(N)$', fontsize = 18)
        ax.set_xlabel('$Log_{10}(M)$', fontsize = 18)
        ax.set_xlim(min(tmp[0])-1,max(tmp[0])+1)
        ax.set_ylim(min(log10(tmp[1][where(tmp[1]!=0)]))-1,(max(log10(tmp[1][where(tmp[1]!=0)]))+1))

def SchtrGraph(bins):
    # Graphics of the mass function for each quartile
    import matplotlib.gridspec as gridspec
    fig, axes = plt.subplots( nrows=2, ncols=4, figsize=(15,20) )
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.3)
    gs = gridspec.GridSpec(4,2)
    ax0 = plt.subplot(gs[0, 0])
    ax1 = plt.subplot(gs[0, 1])
    ax2 = plt.subplot(gs[1, 0])
    ax3 = plt.subplot(gs[1, 1])
    ax4 = plt.subplot(gs[2:,:])
    
    # Callable lists
    axs = [ax0,ax1,ax2,ax3,ax4]
    qs = [q1,q2,q3,q4,q5]
    indx = ['1st quartile','2nd quartile','3rd quartile','4th quartile', 'Total']
    
    for ax,q,i in zip(axs,qs,indx):
        # Histo for first quartile
        tmp = histog(log10(q),bins)
        tmp = [tmp[0][where(tmp[1]!=0)],tmp[1][where(tmp[1]!=0)]]
        #print tmp
        logm = linspace(amin(tmp[0])-0.5,amax(tmp[0])+0.5, 100)
        ft = fit(tmp,bins)[0]
        errors = fit(tmp,bins)[1]
        print ft[1],errors[1][1]
        ax.errorbar( tmp[0], log10(tmp[1]), yerr = sqrt(vol*tmp[1])/(vol*tmp[1]), fmt='o', ecolor = 'r', c = 'b', markersize=3,elinewidth=1.5)
        ax.plot(logm, log10(Schechter(logm,ft[0],ft[1],ft[2]) ),'r', 
             label = r"$\alpha$ = " + str(ft[0]) +"\n" + r"d$\alpha$ = " + str(sqrt(errors[0][0]))+"\n"
             + r"$m_\ast$ = " + str(ft[2])  +"\n" + r"d$m_\ast$ = " + str(sqrt(errors[2][2])))
        #ax.bar( tmp[0] , log10(tmp[1]), width = tmp[0][1]-tmp[0][2], alpha = 0.4, align = 'center' )
        ax.legend(prop={'size':10})
        #savetxt(name + "q2.csv",(array([tmp[0], tmp[1], sqrt(vol*tmp[1])/(vol*tmp[1])]).T), delimiter = ',')
        ax.set_title(i, fontsize = 18)
        ax.set_ylabel('$Log_{10}(N)$', fontsize = 18)
        ax.set_xlabel('$Log_{10}(M)$', fontsize = 18)
        ax.set_xlim(min(tmp[0])-1,max(tmp[0])+1)
        ax.set_ylim(min(log10(tmp[1][where(tmp[1]!=0)]))-1,(max(log10(tmp[1][where(tmp[1]!=0)]))+1))

# %% [markdown]
# # Illustris-1 gas particles without r-band filter

# %% [markdown]
# ### Minimum mass allowed 0

# %%
loadHaloes("env1.data",3.0,0,0)
#SchtrGraph(20)
histo(20)
# Out:
# number of haloes before: 191443
# number of haloes after: 191443
# 47861
#  47861 47861 47861 191444 [  1.12457571e+11   6.16962857e+09   3.31471429e+09 ...,   3.62000000e+07
#    1.43242857e+08   1.12671429e+08] [  2.59902431e+13   1.66000714e+10   4.96090000e+09 ...,   9.21714286e+07
#    1.25185714e+08   9.34714286e+07] [  1.57242714e+10   4.43423857e+10   7.02871429e+08 ...,   1.75000000e+07
#    8.00000000e+05   1.60000000e+06] [  1.71835000e+10   3.88608571e+09   3.03365714e+09 ...,   3.40000000e+06
#    6.57142857e+05   6.71428571e+05] [  2.59902431e+13   1.12457571e+11   6.16962857e+09 ...,   1.25185714e+08
#    1.12671429e+08   9.34714286e+07]

# %%
loadHaloes("env1_19.data",3.0,0,10**10.5)
#histo(15)
SchtrGraph(10)
# Out:
# number of haloes before: 16163
# number of haloes after: 4843
# 1211 1211 1211 1211 4844 [  2.59902431e+13   1.12457571e+11   4.60595857e+10 ...,   3.37837000e+10
#    3.39521857e+10   3.47895286e+10] [  4.94443571e+10   4.06337857e+10   4.65191571e+10 ...,   3.38274714e+10
#    3.23482857e+10   3.35748286e+10] [  4.21839143e+10   3.56068000e+10   6.13796143e+10 ...,   3.32054857e+10
#    3.34106857e+10   3.43434571e+10] [  4.79459857e+10   1.03071871e+11   4.75031571e+10 ...,   3.23152286e+10
#    3.25982143e+10   3.19451857e+10] [  2.59902431e+13   1.12457571e+11   4.60595857e+10 ...,   3.19451857e+10
#    3.23482857e+10   3.35748286e+10]
# 0.0010731096704
#  2.44427617711e-06
# 0.00121014586624 4.64305395521e-08
# 0.00134977605534
#  2.70291206648e-08
# 0.00152957027401 1.9908279534e-07
# 0.0154353539779
#  3.17477094614e-05

# %% [markdown]
# ### Minimum mass allowed $10^{8.5} M_{\odot}$

# %%
loadHaloes("env1.data",3.0,0,10**(8.5))
#histo(15)
SchtrGraph(15)
# Out:
# number of haloes before: 191443
# number of haloes after: 158115
# 39529
#  39529 39529 39529 158116 [  1.12457571e+11   6.16962857e+09   3.31471429e+09 ...,   3.30571429e+08
#    4.31614286e+08   4.57114286e+08] [  2.59902431e+13   1.66000714e+10   4.96090000e+09 ...,   3.37200000e+08
#    4.60914286e+08   3.26285714e+08] [  4.43423857e+10   7.02871429e+08   8.01600000e+08 ...,   3.47571429e+08
#    4.21471429e+08   4.18157143e+08] [  1.71835000e+10   3.88608571e+09   3.03365714e+09 ...,   4.05985714e+08
#    3.52885714e+08   4.40714286e+08] [  2.59902431e+13   1.12457571e+11   6.16962857e+09 ...,   4.60914286e+08
#    3.26285714e+08   4.57114286e+08]
# 0.00621424295648
#  1.42162825744e-07
# 0.0119285788877 8.39615287641e-07
# 0.0078459984581
#  3.77821307182e-07
# 0.00878507784882 8.3408468389e-07
# 0.0441397405117
#  1.87044293196e-05

# %% [markdown]
# # Illustris-1 gas particles r-band filter $mag <-19$

# %% [markdown]
# ### Minimum mass allowed 0

# %%
loadHaloes("env1_19.data",3.0,0,0)
histo(20)
# Out:
# number of haloes before: 16163
# number of haloes after: 16163
# 4041 4041 4041 4041 16164 [  2.59902431e+13   1.12457571e+11   6.16962857e+09 ...,   7.08807143e+09
#    1.82989429e+10   3.17308571e+09] [  3.31471429e+09   1.52621857e+10   3.11390571e+10 ...,   9.41768571e+09
#    3.30891429e+09   7.91062857e+09] [  1.33305714e+09   2.02756143e+10   7.64257143e+09 ...,   1.20071857e+10
#    6.26015714e+09   3.85747143e+09] [  1.71835000e+10   1.10882857e+10   8.87185714e+09 ...,   1.26589429e+10
#    1.51561143e+10   1.16273000e+10] [  2.59902431e+13   1.12457571e+11   6.16962857e+09 ...,   7.91062857e+09
#    3.17308571e+09   3.85747143e+09]

# %% [markdown]
# ### Minimum mass allowed $10^{10.2} M_{\odot}$

# %%
loadHaloes("env1_19.data",3.0,0,10**10.2)
histo(10)
# Out:
# number of haloes before: 16163
# number of haloes after: 12165
# 3042 3041 3041 3041 12165 [  2.59902431e+13   1.12457571e+11   1.66000714e+10 ...,   1.76016714e+10
#    1.65600429e+10   1.82989429e+10] [  2.98913000e+10   2.66264143e+10   1.66657429e+10 ...,   1.75011143e+10
#    1.58841714e+10   1.72870000e+10] [  2.02756143e+10   1.86016286e+10   4.21839143e+10 ...,   1.71243571e+10
#    1.81305571e+10   1.81774143e+10] [  1.71835000e+10   1.90278857e+10   1.79098429e+10 ...,   1.65935429e+10
#    1.66221857e+10   1.69382571e+10] [  2.59902431e+13   1.12457571e+11   1.66000714e+10 ...,   1.65600429e+10
#    1.82989429e+10   1.72870000e+10]

# %%
loadHaloes("env2.data",3.0,0,0)
histo(15)
# Out:
# number of haloes before: 94504
# number of haloes after: 94504
# 23626 23626 23626 23626 94504 [  2.23333343e+11   7.20269857e+10   7.17870571e+10 ...,   2.37071429e+08
#    7.11428571e+07   3.45757143e+08] [  3.53878313e+13   5.62002286e+10   3.61198000e+10 ...,   4.33285714e+07
#    1.86142857e+07   6.24285714e+06] [  2.69586000e+10   3.73875714e+09   7.68057143e+08 ...,   4.53285714e+07
#    1.17000000e+07   2.75857143e+07] [  2.11229714e+10   1.72811714e+10   2.91218571e+09 ...,   7.65714286e+06
#    3.68285714e+07   2.79142857e+07] [  3.53878313e+13   2.23333343e+11   5.62002286e+10 ...,   6.24285714e+06
#    3.45757143e+08   2.75857143e+07]

# %%
loadHaloes("env3.data",3.0,1,0)
histo(12)
# Out:
# number of haloes before: 31161
# number of haloes after: 31149
# 7788 7787 7787 7787 31149 [  3.14497600e+14   3.42010742e+13   5.50964443e+12 ...,   1.41086857e+10
#    1.37055857e+10   1.37055857e+10] [  2.01512386e+12   1.20447889e+12   1.27663476e+12 ...,   1.37055857e+10
#    1.69304286e+10   8.06211429e+09] [  3.74001203e+12   3.91012286e+10   2.86204857e+10 ...,   1.41086857e+10
#    1.33024714e+10   1.45118000e+10] [  6.00627000e+10   1.26978200e+11   1.04001186e+11 ...,   1.73335286e+10
#    1.53180000e+10   1.16900571e+10] [  3.14497600e+14   3.42010742e+13   5.50964443e+12 ...,   1.69304286e+10
#    1.37055857e+10   8.06211429e+09]

# %%
lis = [0,0,4,-5,6,-10]
min(lis)
# Out:
# -10
