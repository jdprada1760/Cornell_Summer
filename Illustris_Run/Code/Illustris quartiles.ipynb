# %%
# %pylab inline
from scipy import optimize
from IPython.display import display, Math, Latex
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Some useful tools and definitions

# %%
#mass units
M = (10.0**10)/0.7
#vol of illustris run
vol = (75/0.7)**3
print 75/0.7

# Gives the x,y of the histogram for logmasses from the given array of mass
def histog( mf, nbins ):
    hist, bin_edges = np.histogram(mf, bins = nbins)
    # Obtains the center point for each bin
    xcenter = (bin_edges[:-1] + bin_edges[1:])/2
    return np.array(xcenter), np.array(hist/vol)

# Schechter function
def Schechter(m,alpha,phi_s,m_s):
    MHI = 10.**m
    M_s = 10.**m_s
    return np.log(10.)*phi_s*((MHI/M_s)**(alpha+1))*numpy.exp(-MHI/M_s)

# Returns the fitted parameterts for the Schechter function given a mass distribution
def fit(mf,bins):
    # tmp[0]:mj,  tmp[1]:nj
    tmp = histog(log100(mf),bins)
    return optimize.curve_fit(Schechter,tmp[0] ,tmp[1],p0=[-2.0,0,12], sigma = np.sqrt(tmp[1]*vol)/vol, maxfev = 100000)
# Out:
# 107.142857143

# %% [markdown]
# ## Loading function

# %%
# loads the file with halo masses and makes the quartiles
# file formated env,mass
# j defines if we treat gass or dm j = 0,1
# minMass minimum mass allowed to have into account a halo
def loadHaloes(name, neigh, j, minMass):
    table = np.loadtxt(name, skiprows = 0, delimiter = ',').T
    #table[0] = neigh/(np.pi*table[0]+1e-9)
    print "number of haloes before: " + str(len(table.T))
    
    # Only take the haloes with not null mass
    lsigma = table[0][where((M*table[j+1]) > minMass)]
    mass = M*table[j+1][where(M*table[j+1]> minMass)]
    
    print "number of haloes after: " + str(len(mass))

    # Calculates the first quartile of logsigma
    global q1
    global q2
    global q3
    global q4
    global q5
    q5 = M*table[j+1][where(M*table[j+1]> minMass)]

    
    q = np.percentile(lsigma,25)
    # Keeps first quartile
    q1 = mass[where(lsigma <= q)]
    # Removes fist quartile from lsigma
    mass = mass[where(lsigma > q)]
    lsigma = lsigma[where(lsigma > q)]
    # Second quartile
    q = np.percentile(lsigma,33.333333)
    q2 = mass[where(lsigma <= q)]
    mass = mass[where(lsigma > q)]
    lsigma = lsigma[where(lsigma > q)]
    # Third and Fourth quartile
    q = np.percentile(lsigma,50)
    q3 = mass[where(lsigma <= q)]
    q4 = mass[where(lsigma >= q)]
    
    # verify the length of each quartile
    print len(q1),len(q2),len(q3),len(q4), sum([len(q1),len(q2),len(q3),len(q4)]),q1,q2,q3,q4,q5

# %% [markdown]
# ## Histogram graphing function

# %%
def histo(bins):
    # Graphics of the mass function for each quartile
    import matplotlib.gridspec as gridspec
    fig, axes = plt.subplots( nrows=2, ncols=4, figsize=(15,20) )
    plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.3)
    gs = gridspec.GridSpec(4,2)
    ax0 = plt.subplot(gs[0, 0])
    ax1 = plt.subplot(gs[0, 1])
    ax2 = plt.subplot(gs[1, 0])
    ax3 = plt.subplot(gs[1, 1])
    ax4 = plt.subplot(gs[2:,:])
    
    # Callable lists
    axs = [ax0,ax1,ax2,ax3,ax4]
    qs = [q1,q2,q3,q4,q5]
    indx = ['1st quartile','2nd quartile','3rd quartile','4th quartile', 'Total']
    
    for ax,q,i in zip(axs,qs,indx):
        # Histo for first quartile
        tmp = histog(log10(q),bins)
        tmp[1][where(tmp[1]==0)] = 1
        ax.errorbar( tmp[0], log10(tmp[1]), yerr = sqrt(vol*tmp[1])/(vol*tmp[1]), fmt='o', ecolor = 'r', c = 'b', markersize=3,elinewidth=1.5)
        #ax.bar( tmp[0] , log10(tmp[1]), width = tmp[0][1]-tmp[0][2], alpha = 0.4, align = 'center' )
        ax.set_title(i, fontsize = 18)
        ax.set_ylabel('$Log_{10}(N)$', fontsize = 18)
        ax.set_xlabel('$Log_{10}(M)$', fontsize = 18)
        ax.set_xlim(min(tmp[0])-1,max(tmp[0])+1)
        ax.set_ylim(min(log10(tmp[1][where(tmp[1]!=0)]))-1,(max(log10(tmp[1][where(tmp[1]!=0)]))+1))

# %% [markdown]
# # Illustris-1 gas particles without r-band filter

# %% [markdown]
# ### Minimum mass allowed 0

# %%
loadHaloes("env1.data",3.0,1,0)
histo(20)
# Out:
# number of haloes before: 191443
# number of haloes after: 188143
# 47036
#  47036 47036 47036 188144 [  3.09338414e+13   7.76337541e+12   3.92532043e+12 ...,   6.80242857e+08
#    6.30000000e+06   4.15700000e+08] [  2.87458538e+14   3.20992824e+12   3.63875689e+12 ...,   1.42977143e+09
#    1.32268571e+09   6.30000000e+06] [  2.78904829e+11   3.38060571e+11   2.50958300e+11 ...,   1.32268571e+09
#    1.38567143e+09   1.36048571e+09] [  4.99472857e+10   2.31596571e+10   2.36887429e+10 ...,   1.27860000e+09
#    1.20931429e+09   1.15262857e+09] [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   6.30000000e+06
#    6.30000000e+06   4.15700000e+08]

# %% [markdown]
# ### Minimum mass allowed $10^{10} M_{\odot}$

# %%
loadHaloes("env1.data",3.0,1,10**(10))
histo(15)
# Out:
# number of haloes before: 191443
# number of haloes after: 115994
# 28999 28998 28999 28999 115995 [  3.09338414e+13   7.76337541e+12   3.92532043e+12 ...,   1.03547714e+10
#    1.00713429e+10   1.01280286e+10] [  2.87458538e+14   3.20992824e+12   3.63875689e+12 ...,   1.00461429e+10
#    1.02414000e+10   1.00461429e+10] [  2.78904829e+11   3.38060571e+11   2.50958300e+11 ...,   1.00083571e+10
#    1.00713429e+10   1.00272429e+10]
#  [  4.99472857e+10   2.31596571e+10   2.36887429e+10 ...,   1.00839286e+10
#    1.02099000e+10   1.01595143e+10] [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   1.00461429e+10
#    1.01595143e+10   1.00272429e+10]

# %% [markdown]
# # Illustris-1 gas particles r-band filter $mag <-19$

# %% [markdown]
# ### Minimum mass allowed 0

# %%
loadHaloes("env1_19.data",3.0,1,0)
histo(20)
# Out:
# number of haloes before: 16163
# number of haloes after: 16147
# 4037 4037 4037 4037 16148 [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   6.93152286e+10
#    5.43436429e+10   4.90088000e+10] [  3.92532043e+12   3.46605770e+12   1.08252694e+12 ...,   6.25317286e+10
#    7.63191857e+10   6.09948857e+10] [  1.71162329e+11   1.08133029e+11   7.77237571e+10 ...,   7.95944143e+10
#    8.41671429e+10   3.40120143e+10] [  4.99472857e+10   8.03187571e+10   1.22235414e+11 ...,   8.72282286e+10
#    7.42784714e+10   9.26638571e+10] [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   6.09948857e+10
#    4.90088000e+10   3.40120143e+10]

# %% [markdown]
# ### Minimum mass allowed $10^{11} M_{\odot}$

# %%
loadHaloes("env1_19.data",3.0,1,10**11)
histo(15)
# Out:
# number of haloes before: 16163
# number of haloes after: 13743
# 3436 3436 3436 3436 13744 [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   1.01462886e+11
#    1.00946400e+11   1.02640714e+11] [  3.92532043e+12   2.73110200e+11   2.78904829e+11 ...,   1.03239071e+11
#    1.13688314e+11   1.02357271e+11] [  1.08133029e+11   1.84880514e+11   1.29195286e+11 ...,   1.14085129e+11
#    1.17379257e+11   1.03264257e+11] [  1.22235414e+11   1.07263829e+11   6.60777943e+11 ...,   1.00133900e+11
#    1.03856329e+11   1.08699886e+11] [  2.87458538e+14   3.09338414e+13   7.76337541e+12 ...,   1.02357271e+11
#    1.00946400e+11   1.02640714e+11]

# %%
loadHaloes("env2.data",3.0,1,10**10.2)
histo(15)
# Out:
# number of haloes before: 94504
# number of haloes after: 72874
# 18219 18218 18219 18219 72875 [  3.00604248e+13   4.55463736e+12   3.88916103e+12 ...,   1.60738286e+10
#    1.58722714e+10   1.59226571e+10] [  3.00132031e+14   3.10239999e+12   1.48519146e+12 ...,   1.65777143e+10
#    1.66281000e+10   1.62753857e+10] [  3.38104657e+11   1.99386014e+11   1.74242300e+11 ...,   1.64769286e+10
#    1.61242143e+10   1.65273143e+10] [  6.54542429e+10   7.76985714e+10   3.05352286e+10 ...,   1.71319857e+10
#    1.58722714e+10   1.58722714e+10] [  3.00132031e+14   3.00604248e+13   3.10239999e+12 ...,   1.66281000e+10
#    1.58722714e+10   1.62753857e+10]

# %%
loadHaloes("env3.data",3.0,1,10**11)
histo(12)
# Out:
# number of haloes before: 31161
# number of haloes after: 16042
# 4011 4010 4011 4011 16043 [  3.14497600e+14   3.42010742e+13   5.50964443e+12 ...,   1.06016714e+11
#    1.12466400e+11   1.01985671e+11] [  2.01512386e+12   1.20447889e+12   1.27663476e+12 ...,   1.03194986e+11
#    1.04404300e+11   1.06822929e+11] [  3.74001203e+12   8.02985929e+11   6.30859914e+11 ...,   1.01179457e+11
#    1.01179457e+11   1.00373243e+11] [  1.26978200e+11   1.04001186e+11   1.20609131e+12 ...,   1.01179457e+11
#    1.00776343e+11   1.05613614e+11] [  3.14497600e+14   3.42010742e+13   5.50964443e+12 ...,   1.01179457e+11
#    1.01179457e+11   1.00373243e+11]
